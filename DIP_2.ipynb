# %%
import cv2 as cv2
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.pylab as plt
from  PIL import Image

# %%
img=cv2.imread('/content/240_F_580908469_ameHMXlxIeyOfFK9YX0VDb6xsebULfPr.jpg')
cv2_imshow(img);
# Out:
# <PIL.Image.Image image mode=RGB size=420x240>

# %%
img=cv2.imread('/content/240_F_580908469_ameHMXlxIeyOfFK9YX0VDb6xsebULfPr.jpg')
negativeimg=255-img;
cv2_imshow(negativeimg);
# Out:
# <PIL.Image.Image image mode=RGB size=420x240>

# %%
img=cv2.imread('/content/240_F_580908469_ameHMXlxIeyOfFK9YX0VDb6xsebULfPr.jpg');
c=255/np.log(1+np.max(img));
log_img_c=c*(np.log(img+1));
cv2_imshow(log_img_c);
grayimg=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY);
c=255/np.log(1+np.max(grayimg));
log_img_g=c*(np.log(grayimg+1));
cv2_imshow(log_img_g);
# Out:
# <ipython-input-26-8ed7ba166f1a>:3: RuntimeWarning: divide by zero encountered in log
#   log_img_c=c*(np.log(img+1));
# <PIL.Image.Image image mode=RGB size=420x240>
# <ipython-input-26-8ed7ba166f1a>:7: RuntimeWarning: divide by zero encountered in log
#   log_img_g=c*(np.log(grayimg+1));
# <PIL.Image.Image image mode=L size=420x240>

# %%
img=cv2.imread('/content/240_F_580908469_ameHMXlxIeyOfFK9YX0VDb6xsebULfPr.jpg');
c=255/np.log(1+np.max(img));
img1=255*(img/255)**(2);
img2=255*(img/255)**(3);
img3=255*(img/255)**(4);
concatenated_img = np.hstack([img1, img2,img3])
cv2_imshow(concatenated_img);
# Out:
# <PIL.Image.Image image mode=RGB size=1260x240>

# %%
img_h=cv2.flip(grayimg,1);
img_v=cv2.flip(grayimg,0);
concatenated_img = np.hstack([img_h, img_v])
cv2_imshow(concatenated_img);
# Out:
# <PIL.Image.Image image mode=L size=840x240>
